# %% [markdown]
# ### Regresión: Ejercicio 8
#
# *Empezamos desarrollando el lado izquierdo de la ecuación:*
#
# $\frac{1}{n}\sum_{i=1}^{n}(w\hat{e_{i}}+ (1-w)\tilde{e_{i}})^{2}$
#
# $\frac{1}{n}\sum_{i=1}^{n}(w^{2}\hat{e_{i}}^{2})+\frac{1}{n}\sum_{i=1}^{n}(2w)(1-w)\hat{e_{i}}\tilde{e_{i}} +\frac{1}{n}\sum_{i=1}^{n}(1-w)^{2}\tilde{e_{i}}^{2}$
#
# *De los datos del problema se conoce que :*
#
# $\tilde{\sigma ^{2}} =\frac{1}{n}\sum_{i=1}^{n}\tilde{e_{i}^{2}} \quad \hat{\sigma ^{2}} =\frac{1}{n}\sum_{i=1}^{n}\tilde{e_{i}^{2}}$
#
# *Reemplazamos :*
#
# $\hat{\sigma ^{2}} w^{2} + (2w)(1-w)\frac{1}{n}\sum_{i=1}^{n}\hat{e_{i}}\tilde{e_{i}}+ \tilde{\sigma ^{2}}(1-w)^{2}$
#
# $\hat{\sigma ^{2}} w^{2} + (2w)(1-w)\frac{1}{n}\sum_{i=1}^{n}\hat{e_{i}}(y_{i}-x_{1i}^{'}\tilde{\beta _{1}})+ \tilde{\sigma ^{2}}(1-w)^{2}$
#
# *Desarrollamos la siguiente expresión:*
#
# $\sum_{i=1}^{n}\hat{e_{i}}(y_{i}-x_{1i}^{'}\tilde{\beta _{1}})$
#
# $\sum_{i=1}^{n}(\hat{e_{i}}y_{i})-\tilde{\beta _{1}}\sum_{i=1}^{n}(\hat{e_{i}}x_{1i}^{'})$
#
# *Debido a la exogeneidad se cumple que:*
#
# $\sum_{i=1}^{n}(\hat{e_{i}}x_{1i}^{'})=0 $
#
# *Entonces,*
#
# $\sum_{i=1}^{n}\hat{e_{i}}\tilde{e_{i}}= \sum_{i=1}^{n}(\hat{e_{i}}y_{i})$
#
# $\sum_{i=1}^{n}\hat{e_{i}}\tilde{e_{i}}= \sum_{i=1}^{n}\hat{e_{i}}(x_{1i}^{'}\hat{\beta _{1}}+x_{2i}^{'}\hat{\beta _{2}}+\hat{e_{i}}^{'})$
#
# $\sum_{i=1}^{n}\hat{e_{i}}\tilde{e_{i}}=\sum_{i=1}^{n}\hat{e_{i}}\hat{e_{i}}$
#
# *Reemplazamos:*
#
# $\hat{\sigma ^{2}} w^{2} + (2w)(1-w)\frac{1}{n}\sum_{i=1}^{n}\hat{e_{i}}^{2}+ \tilde{\sigma ^{2}}(1-w)^{2}$
#
# $\hat{\sigma ^{2}} w^{2} + (2w)(1-w)\hat{\sigma}^{2}+ \tilde{\sigma ^{2}}(1-w)^{2}$
#
# $\hat{\sigma^{2}} (w^{2}+ 2w+(1-w)) + \tilde{\sigma}^{2}(1-w)^{2}$
#
# *Igualamos al lado derecho de la expresión inicial proporcionado por el problema:*
#
# $\hat{\sigma^{2}} (w^{2}+ 2w+(1-w)) + \tilde{\sigma}^{2}(1-w)^{2} = (1-a)\hat{\sigma^{2}}+ a(\tilde{\sigma^{2}})$
#
# *A partir de ello se puede deducir el valor de a :*
#
# $ a = 1-2w+w^{2} \quad 1-a = 2w-w^{2} $

# %% [markdown]
# ### Regresión (cont.): Ejercicio 8
#
# *Partimos de la expresión del estimador :*
#
# $\hat{\beta}=\frac{\sum_{i=1}^{n}x_{i}^{3}y_{i}}{\sum_{i=1}^{n}x_{i}^{4}}$
#
# $\hat{\beta}=\frac{\sum_{i=1}^{n}(x_{i}^{3}(x_{i}\beta + e_{i})}{\sum_{i=1}^{n}x_{i}^{4}}$
#
# $\hat{\beta}= \beta*\frac{\sum_{i=1}^{n}x_{i}^{3}(x_{i})}{\sum_{i=1}^{n}x_{i}^{4}}+\frac{\sum_{i=1}^{n}x_{i}^{3}(e_{i})}{\sum_{i=1}^{n}x_{i}^{4}}  $
#
# $\hat{\beta}= \beta +\frac{\sum_{i=1}^{n}x_{i}^{3}(e_{i})}{\sum_{i=1}^{n}x_{i}^{4}}  $
#
# *El error del estimador se calcula como:*
#
# $\hat{\beta}-\beta = \frac{\sum_{i=1}^{n}x_{i}^{3}(e_{i})}{\sum_{i=1}^{n}x_{i}^{4}}$
#
# *Multiplicamos ambos miembros de la ecuaciòn por $\sqrt{n}$ :*
#
# $\sqrt{n}*(\hat{\beta}-\beta) = \sqrt{n}(\frac{\sum_{i=1}^{n}x_{i}^{3}(e_{i})}{\sum_{i=1}^{n}x_{i}^{4}})$
#
# *Aplicamos el Teorema del Límite Centra al numerador:*
#
# $\frac{1}{\sqrt{n}}\sum_{i=1}^{n}x_{i}^{3}(e_{i})\overset{d}{\rightarrow}N(0,\Omega)$
#
# $\sum_{i=1}^{n}x_{i}^{3}(e_{i})\overset{d}{\rightarrow}N(0,E\left[(x_{i}^{3})^{2}e_{i}^{2}\right ] $
#
# *Asimismo, aplicamos La Ley de Grandes Números al denominador :*
#
# $\frac{1}{{n}}\sum_{i=1}^{n}x_{i}^{4}\overset{p}{\rightarrow}N(0,\Omega)$
#
# $\sum_{i=1}^{n}x_{i}^{4}\approx n*E\left [(x_{i}^{4}\right]$
#
# *Reemplazamos en la expresión anterior:*
#
# $\sqrt{n}(\hat{\beta} -\beta) \approx \sqrt{n}*\frac{\sqrt{n}N(0,E\left[(x_{i}^{6}\right]*E\left[e_{i}^{2}\right]}{n*E\left[(x_{i}^{4}\right]} $
#
# $\sqrt{n}(\hat{\beta} -\beta) \approx N(0,\frac{E\left[x_{i}^{6}\right]*\sigma^{2}}{E\left[x_{i}^{4}\right]^{2}})$

# %% [markdown]
# ### Multinomial Response : Ejercicio 3
# **a) ¿Cómo estimarìas $\beta_j$? Justifica tu respuesta discutiendo la naturaleza de la vaariable patents**
#
# *Para estimar los $\beta_j$, utilizaríamos regresión de Poisson debido a la naturaleza del número de patentes, que es una variable de conteo. La función de densidad para una variable de conteo como las patentes está mejor representada por una distribución de Poisson, y la media condicional en el modelo es exponencial, lo que concuerda con la estructura del modelo propuesto*
#
# **b) ¿Cómo interpretas $\beta_1$:**
#
# *$\beta_1$ es la elasticidad del número de patentes con respecto a las ventas anuales de la firma. Un aumento de 1% en las ventas està asciado con un cambio aproximado de  $\beta_1%$ en el número de patentes ceteris paribus.*
#
# **b) Estima el efecto parcial de RD sobre $E\left[patents\mid sales, RD\right]$:**
#
# $\frac{\partial E\left[patents\mid sales, RD\right]}{\partial RD}= \frac{\partial exp(\beta _{1}log (sales)+\beta _{2}RD + \beta _{3}RD^{2})}{\partial RD}$
#
# $\frac{\partial E\left[patents\mid sales, RD\right]}{\partial RD}=\partial E\left[patents\mid sales, RD\right]*(\beta _{2}+2\beta _{3}*RD)$
